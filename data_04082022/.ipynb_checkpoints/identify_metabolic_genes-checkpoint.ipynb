# %%
import pandas as pd
import cobra
from Bio import Entrez
import sys
from copy import deepcopy

# %% [markdown]
# # Read RNAseq

# %%
df_rnaseq = pd.read_excel("3_deseq2_ccr2dep_vs_wt_padj0.05.res.xlsx", index_col=0)
all_mouse_genes = list(set(df_rnaseq.index))
print("found %d genes."%(len(all_mouse_genes))) # literature indicates that mouse has around 30,000 genes, why?
df_rnaseq.head()
# Out:
# found 53656 genes.
#        ccr2_depleted      wildtype      baseMean  log2FoldChange     lfcSE  \
# Stat1     284.299639   4238.106145   1818.910529       -3.898472  0.058922
# Cxcr2    8241.748567  18107.807382  12531.561504       -1.135729  0.020185
# Btg2     6912.940600  15421.908871  12159.637873       -1.157757  0.023470
# Ptprc    5591.037382  10755.033116  10484.034291       -0.944082  0.022199
# Rgs2     9578.267700  18723.366669  17714.065440       -0.966969  0.021236
#
#             stat  pvalue  padj
# Stat1 -66.163332     0.0   0.0
# Cxcr2 -56.266474     0.0   0.0
# Btg2  -49.328711     0.0   0.0
# Ptprc -42.527642     0.0   0.0
# Rgs2  -45.533714     0.0   0.0

# %% [markdown]
# # Test function

# %%
id_list = ['11754']

Entrez.email = "*****@gmail.com"

def retrieve_annotation(id_list):

    request = Entrez.epost("gene",id=",".join(id_list))
    try:
        result = Entrez.read(request)
    except RuntimeError as e:

        print("An error occurred while retrieving the annotations.")
        print("The error returned was %s" % e)
        sys.exit(-1)

    webEnv = result["WebEnv"]
    queryKey = result["QueryKey"]
    data = Entrez.esummary(db="gene", webenv=webEnv, query_key =
            queryKey)
    annotations = Entrez.read(data)

    print("Retrieved %d annotations for %d genes" % (len(annotations), len(id_list)))

    return annotations

annotation=retrieve_annotation(id_list)
annotation
# Out:
# Retrieved 1 annotations for 1 genes
# {'DocumentSummarySet': DictElement({'DocumentSummary': [DictElement({'Name': 'Aoc3', 'Description': 'amine oxidase, copper containing 3', 'Status': '0', 'CurrentID': '0', 'Chromosome': '11', 'GeneticSource': 'genomic', 'MapLocation': '11 D', 'OtherAliases': 'SSAO, VAP1', 'OtherDesignations': 'membrane primary amine oxidase|VAP-1|copper amine oxidase|semicarbazide-sensitive amine oxidase|vascular adhesion protein 1', 'NomenclatureSymbol': 'Aoc3', 'NomenclatureName': 'amine oxidase, copper containing 3', 'NomenclatureStatus': 'Official', 'Mim': [], 'GenomicInfo': [{'ChrLoc': '11', 'ChrAccVer': 'NC_000077.7', 'ChrStart': '101221431', 'ChrStop': '101230255', 'ExonCount': '6'}], 'GeneWeight': '5556', 'Summary': '', 'ChrSort': '11', 'ChrStart': '101221431', 'Organism': {'ScientificName': 'Mus musculus', 'CommonName': 'house mouse', 'TaxID': '10090'}, 'LocationHist': [{'AnnotationRelease': '109', 'AssemblyAccVer': 'GCF_000001635.27', 'ChrAccVer': 'NC_000077.7', 'ChrStart': '101221431', 'ChrStop': '101230255'}, {'AnnotationRelease': '108.20200622', 'AssemblyAccVer': 'GCF_000001635.26', 'ChrAccVer': 'NC_000077.6', 'ChrStart': '101330605', 'ChrStop': '101339429'}, {'AnnotationRelease': '108', 'AssemblyAccVer': 'GCF_000001635.26', 'ChrAccVer': 'NC_000077.6', 'ChrStart': '101330605', 'ChrStop': '101339429'}, {'AnnotationRelease': '37.2', 'AssemblyAccVer': 'GCF_000001635.18', 'ChrAccVer': 'NC_000077.5', 'ChrStart': '101191919', 'ChrStop': '101200743'}]}, attributes={'uid': '11754'})], 'DbBuild': 'Build220411-2240m.1'}, attributes={'status': 'OK'})}

# %%
annotation['DocumentSummarySet']['DocumentSummary'][0].keys()
# Out:
# dict_keys(['Name', 'Description', 'Status', 'CurrentID', 'Chromosome', 'GeneticSource', 'MapLocation', 'OtherAliases', 'OtherDesignations', 'NomenclatureSymbol', 'NomenclatureName', 'NomenclatureStatus', 'Mim', 'GenomicInfo', 'GeneWeight', 'Summary', 'ChrSort', 'ChrStart', 'Organism', 'LocationHist'])

# %% [markdown]
# # Khodaee2020SciRep

# %%
model = cobra.io.read_sbml_model("../mouse_metabolic_model/Khodaee2020SciRep/iMM3254.xml")

# %%
all_metabolic_genes = list(set([g.name for g in model.genes]))

# %%
shared_genes = list(set(all_mouse_genes).intersection(set(all_metabolic_genes)))
print("found %d shared genes."%(len(shared_genes)))
# Out:
# found 3173 shared genes.

# %%
res = []
for g in model.genes:
    if g.name in shared_genes:
        res2 = [g.name]
        for db in ['mgi', 'ccds', 'ncbigene']:
            if db in g.annotation:
                res2.append(g.annotation[db])
            else:
                res2.append(None)
        res.append(res2)
df_res = pd.DataFrame(res, columns=['Symbol','MGI','CCDS','NCBI']).set_index('Symbol')
df_res.head()
# Out:
#                  MGI         CCDS    NCBI
# Symbol
# Aoc3     MGI:1306797  CCDS25465.1   11754
# Aoc2     MGI:2668431  CCDS25464.1  237940
# Aoc1     MGI:1923757  CCDS51767.1   76507
# Cyp24a1    MGI:88593  CCDS17122.1   13081
# Cyp27b1  MGI:1098274  CCDS24224.2   13115

# %%
df_res[df_res.NCBI.isnull()]
# Out:
# Empty DataFrame
# Columns: [MGI, CCDS, NCBI]
# Index: []

# %%
# add genome annotation
annotations = retrieve_annotation(list(df_res.NCBI))['DocumentSummarySet']['DocumentSummary']
# Out:
# Retrieved 1 annotations for 3173 genes

# %%
df_annot = None
for annot in annotations:
    df_tmp = pd.DataFrame.from_dict(annot, orient="index", columns=['Value'])
    df_tmp = df_tmp.rename(columns=df_tmp.loc['Name'])
    if df_annot is None:
        df_annot = deepcopy(df_tmp)
    else:
        df_annot = pd.merge(df_annot, df_tmp, left_index=True, right_index=True, how='outer')
df_annot = df_annot.drop('Name').T
df_annot.head()
# Out:
#                                                Description Status CurrentID  \
# Aoc3                    amine oxidase, copper containing 3      0         0
# Aoc2     amine oxidase, copper containing 2 (retina-spe...      0         0
# Aoc1                    amine oxidase, copper-containing 1      0         0
# Cyp24a1  cytochrome P450, family 24, subfamily a, polyp...      0         0
# Cyp27b1  cytochrome P450, family 27, subfamily b, polyp...      0         0
#
#         Chromosome GeneticSource MapLocation  \
# Aoc3            11       genomic        11 D
# Aoc2            11       genomic        11 D
# Aoc1             6       genomic  6 23.78 cM
# Cyp24a1          2       genomic  2 91.91 cM
# Cyp27b1         10       genomic       10 D3
#
#                                               OtherAliases  \
# Aoc3                                            SSAO, VAP1
# Aoc2                                                   RAO
# Aoc1                              1600012D06Rik, Abp1, DAO
# Cyp24a1                              24-OHase, CP24, Cyp24
# Cyp27b1  Cp2b, Cyp1, Cyp27b, Cyp40, P450c1, Pddr, Vdd1,...
#
#                                          OtherDesignations NomenclatureSymbol  \
# Aoc3     membrane primary amine oxidase|VAP-1|copper am...               Aoc3
# Aoc2     retina-specific copper amine oxidase|retina-sp...               Aoc2
# Aoc1     amiloride-sensitive amine oxidase [copper-cont...               Aoc1
# Cyp24a1  1,25-dihydroxyvitamin D(3) 24-hydroxylase, mit...            Cyp24a1
# Cyp27b1  25-hydroxyvitamin D-1 alpha hydroxylase, mitoc...            Cyp27b1
#
#                                           NomenclatureName NomenclatureStatus  \
# Aoc3                    amine oxidase, copper containing 3           Official
# Aoc2     amine oxidase, copper containing 2 (retina-spe...           Official
# Aoc1                    amine oxidase, copper-containing 1           Official
# Cyp24a1  cytochrome P450, family 24, subfamily a, polyp...           Official
# Cyp27b1  cytochrome P450, family 27, subfamily b, polyp...           Official
#
#         Mim                                        GenomicInfo GeneWeight  \
# Aoc3     []  [{'ChrLoc': '11', 'ChrAccVer': 'NC_000077.7', ...       5556
# Aoc2     []  [{'ChrLoc': '11', 'ChrAccVer': 'NC_000077.7', ...        534
# Aoc1     []  [{'ChrLoc': '6', 'ChrAccVer': 'NC_000072.7', '...        992
# Cyp24a1  []  [{'ChrLoc': '2', 'ChrAccVer': 'NC_000068.8', '...       3845
# Cyp27b1  []  [{'ChrLoc': '10', 'ChrAccVer': 'NC_000076.7', ...      11544
#
#                                                    Summary ChrSort   ChrStart  \
# Aoc3                                                            11  101221431
# Aoc2                                                            11  101214466
# Aoc1                                                            06   48872188
# Cyp24a1  The protein encoded by this gene localizes to ...      02  170324876
# Cyp27b1                                                         10  126884114
#
#                                                   Organism  \
# Aoc3     {'ScientificName': 'Mus musculus', 'CommonName...
# Aoc2     {'ScientificName': 'Mus musculus', 'CommonName...
# Aoc1     {'ScientificName': 'Mus musculus', 'CommonName...
# Cyp24a1  {'ScientificName': 'Mus musculus', 'CommonName...
# Cyp27b1  {'ScientificName': 'Mus musculus', 'CommonName...
#
#                                               LocationHist
# Aoc3     [{'AnnotationRelease': '109', 'AssemblyAccVer'...
# Aoc2     [{'AnnotationRelease': '109', 'AssemblyAccVer'...
# Aoc1     [{'AnnotationRelease': '109', 'AssemblyAccVer'...
# Cyp24a1  [{'AnnotationRelease': '109', 'AssemblyAccVer'...
# Cyp27b1  [{'AnnotationRelease': '109', 'AssemblyAccVer'...

# %%
df_met_gene_w_annot = pd.merge(df_res, df_annot, left_index=True, right_index=True, how='left')
df_met_gene_w_annot.head()
# Out:
#                  MGI         CCDS    NCBI  \
# Symbol
# Aoc3     MGI:1306797  CCDS25465.1   11754
# Aoc2     MGI:2668431  CCDS25464.1  237940
# Aoc1     MGI:1923757  CCDS51767.1   76507
# Cyp24a1    MGI:88593  CCDS17122.1   13081
# Cyp27b1  MGI:1098274  CCDS24224.2   13115
#
#                                                Description Status CurrentID  \
# Symbol
# Aoc3                    amine oxidase, copper containing 3      0         0
# Aoc2     amine oxidase, copper containing 2 (retina-spe...      0         0
# Aoc1                    amine oxidase, copper-containing 1      0         0
# Cyp24a1  cytochrome P450, family 24, subfamily a, polyp...      0         0
# Cyp27b1  cytochrome P450, family 27, subfamily b, polyp...      0         0
#
#         Chromosome GeneticSource MapLocation  \
# Symbol
# Aoc3            11       genomic        11 D
# Aoc2            11       genomic        11 D
# Aoc1             6       genomic  6 23.78 cM
# Cyp24a1          2       genomic  2 91.91 cM
# Cyp27b1         10       genomic       10 D3
#
#                                               OtherAliases  ...  \
# Symbol                                                      ...
# Aoc3                                            SSAO, VAP1  ...
# Aoc2                                                   RAO  ...
# Aoc1                              1600012D06Rik, Abp1, DAO  ...
# Cyp24a1                              24-OHase, CP24, Cyp24  ...
# Cyp27b1  Cp2b, Cyp1, Cyp27b, Cyp40, P450c1, Pddr, Vdd1,...  ...
#
#                                           NomenclatureName NomenclatureStatus  \
# Symbol
# Aoc3                    amine oxidase, copper containing 3           Official
# Aoc2     amine oxidase, copper containing 2 (retina-spe...           Official
# Aoc1                    amine oxidase, copper-containing 1           Official
# Cyp24a1  cytochrome P450, family 24, subfamily a, polyp...           Official
# Cyp27b1  cytochrome P450, family 27, subfamily b, polyp...           Official
#
#         Mim                                        GenomicInfo GeneWeight  \
# Symbol
# Aoc3     []  [{'ChrLoc': '11', 'ChrAccVer': 'NC_000077.7', ...       5556
# Aoc2     []  [{'ChrLoc': '11', 'ChrAccVer': 'NC_000077.7', ...        534
# Aoc1     []  [{'ChrLoc': '6', 'ChrAccVer': 'NC_000072.7', '...        992
# Cyp24a1  []  [{'ChrLoc': '2', 'ChrAccVer': 'NC_000068.8', '...       3845
# Cyp27b1  []  [{'ChrLoc': '10', 'ChrAccVer': 'NC_000076.7', ...      11544
#
#                                                    Summary ChrSort   ChrStart  \
# Symbol
# Aoc3                                                            11  101221431
# Aoc2                                                            11  101214466
# Aoc1                                                            06   48872188
# Cyp24a1  The protein encoded by this gene localizes to ...      02  170324876
# Cyp27b1                                                         10  126884114
#
#                                                   Organism  \
# Symbol
# Aoc3     {'ScientificName': 'Mus musculus', 'CommonName...
# Aoc2     {'ScientificName': 'Mus musculus', 'CommonName...
# Aoc1     {'ScientificName': 'Mus musculus', 'CommonName...
# Cyp24a1  {'ScientificName': 'Mus musculus', 'CommonName...
# Cyp27b1  {'ScientificName': 'Mus musculus', 'CommonName...
#
#                                               LocationHist
# Symbol
# Aoc3     [{'AnnotationRelease': '109', 'AssemblyAccVer'...
# Aoc2     [{'AnnotationRelease': '109', 'AssemblyAccVer'...
# Aoc1     [{'AnnotationRelease': '109', 'AssemblyAccVer'...
# Cyp24a1  [{'AnnotationRelease': '109', 'AssemblyAccVer'...
# Cyp27b1  [{'AnnotationRelease': '109', 'AssemblyAccVer'...
#
# [5 rows x 22 columns]

# %%
df_met_gene_w_annot[df_met_gene_w_annot.Description.isnull()]
# Out:
#                   MGI                        CCDS    NCBI Description Status  \
# Symbol
# Col4a3bp  MGI:1915268  [CCDS26705.1, CCDS49335.1]   68018         NaN    NaN
# Tsta3       MGI:98857                 CCDS27555.1   22122         NaN    NaN
# Znrd1     MGI:1913386                 CCDS28730.1   66136         NaN    NaN
# Dupd1     MGI:3647127                 CCDS26863.1  435391         NaN    NaN
# Pak7      MGI:1920334                 CCDS16790.1  241656         NaN    NaN
#
#          CurrentID Chromosome GeneticSource MapLocation OtherAliases  ...  \
# Symbol                                                                ...
# Col4a3bp       NaN        NaN           NaN         NaN          NaN  ...
# Tsta3          NaN        NaN           NaN         NaN          NaN  ...
# Znrd1          NaN        NaN           NaN         NaN          NaN  ...
# Dupd1          NaN        NaN           NaN         NaN          NaN  ...
# Pak7           NaN        NaN           NaN         NaN          NaN  ...
#
#          NomenclatureName NomenclatureStatus  Mim GenomicInfo GeneWeight  \
# Symbol
# Col4a3bp              NaN                NaN  NaN         NaN        NaN
# Tsta3                 NaN                NaN  NaN         NaN        NaN
# Znrd1                 NaN                NaN  NaN         NaN        NaN
# Dupd1                 NaN                NaN  NaN         NaN        NaN
# Pak7                  NaN                NaN  NaN         NaN        NaN
#
#          Summary ChrSort ChrStart Organism LocationHist
# Symbol
# Col4a3bp     NaN     NaN      NaN      NaN          NaN
# Tsta3        NaN     NaN      NaN      NaN          NaN
# Znrd1        NaN     NaN      NaN      NaN          NaN
# Dupd1        NaN     NaN      NaN      NaN          NaN
# Pak7         NaN     NaN      NaN      NaN          NaN
#
# [5 rows x 22 columns]

# %%
len(df_met_gene_w_annot)
# Out:
# 3173

# %%
df_met_gene_w_annot.to_csv("metabolic_genes_with_annotation.csv")

# %% [markdown]
# # Wang2021PNAS

# %%
model = cobra.io.read_sbml_model("../mouse_metabolic_model/Wang2021PNAS/Mouse-GEM.xml")
# Out:
# https://identifiers.org/taxonomy/ does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id

# %%
all_metabolic_genes = list(set([g.id for g in model.genes]))

# %%
shared_genes = list(set(all_mouse_genes).intersection(set(all_metabolic_genes)))
print("found %d shared genes."%(len(shared_genes)))
# Out:
# found 2871 shared genes.

# %%
# it has less genes than Khodaee2020SciRep
# stop
